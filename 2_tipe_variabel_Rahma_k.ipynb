# %% [markdown]
# <a href="https://colab.research.google.com/github/rahmakhairun1-jpg/KKA-X1-semester-1-rahmak/blob/main/2_tipe_variabel_Rahma_k.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #konsep dasar variabel

# %%
print("rahmakhairun1@gmail.com")
print("rahmakhairun1@gmail.com")
print("rahmakhairun1@gmail.com")
# Out:
# rahmakhairun1@gmail.com
# rahmakhairun1@gmail.com
# rahmakhairun1@gmail.com

# %%
email_user_1 = "rahmakhairun1@gmail.com"

print(email_user_1)
# Out:
# rahmakhairun1@gmail.com

# %% [markdown]
# #peraturan penulisan variabel

# %%
#sensitif terhadap kapital
email_user_2 = "Keenan Akbar"

print(Email_user_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3282671122.py in <cell line: 0>()
#       2 email_user_2 = "Keenan Akbar"
#       3
# ----> 4 print(Email_user_2)
#
# NameError: name 'Email_user_2' is not defined

# %%
email_user_2 = "Keenan Akbar"

print(email_user_2)
# Out:
# Keenan Akbar

# %%
emailuser2 = "yoga Armando"

print(emailuser2)
# Out:
# yoga Armando

# %%
#hanya boleh menggunakan huruf angka dan underscore
email user 3 = "Dimas esa"

print(email user 3)
# Out:
#   File "/tmp/ipython-input-2368124900.py", line 2
#     email user 3 = "Dimas esa"
#           ^
# SyntaxError: invalid syntax

# %%
emailuser3 = "Dimas esa"

print(emailuser3)
# Out:
# Dimas esa

# %%
#tidak boleh didahului oleh angka
4_email_user = "Hanafi Naufal"

print(4_email_user)
# Out:
#   File "/tmp/ipython-input-1157697013.py", line 2
#     4_email_user = "Hanafi Naufal"
#      ^
# SyntaxError: invalid decimal literal

# %%
#tidak boleh menggunakan kata kunci python
for = "Naufal Fajri"

print(for)
# Out:
#   File "/tmp/ipython-input-3940197380.py", line 2
#     for = "Naufal Fajri"
#         ^
# SyntaxError: invalid syntax

# %%
For = "Naufal Fajri"

print(For)
# Out:
# Naufal Fajri

# %%
print = "Alif Nadya"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2601485791.py in <cell line: 0>()
#       1 print = "Alif Nadya"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Alif Nadya"

print(Print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4162332639.py in <cell line: 0>()
#       1 Print = "Alif Nadya"
#       2
# ----> 3 print(Print)
#
# TypeError: 'str' object is not callable

# %%
_ = "azka alifta"

# %%
print(_)
# Out:
# azka alifta

# %%
_ = "Kenzo Aliando"

# %%
print(_)
# Out:
# Kenzo Aliando

# %%
nama:"ahmad fauzi"
kelas:"X.12"
hobi:"membaca

# %% [markdown]
# #ASSIGNMENT

# %%
#single assignment
beratbadansiswa = 90
print(beratbadansiswa)
# Out:
# 90

# %%
#multiple assignment
nilai_kka_dias, nilai_kka_azka= 99,98
print(nilai_kka_azka)
print(nilai_kka_dias)
# Out:
# 98
# 99

# %%
nilai_kka_dias,nilai_kka_azka= 99,98,70

print(nilai_kka_azka)
print(nilai_kka_dias)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1988995059.py in <cell line: 0>()
# ----> 1 nilai_kka_dias,nilai_kka_azka= 99,98,70
#       2
#       3 print(nilai_kka_azka)
#       4 print(nilai_kka_dias)
#
# ValueError: too many values to unpack (expected 2)

# %%
#chain assignment
usia_anwar=usia_sahda=20
print(usia_anwar)
print(usia_sahda)
# Out:
# 20
# 20

# %% [markdown]
# #latiah soal

# %%
1.
nama="Andi"
print(nama)
# Out:
# Andi

# %%
2.
nama,umur,kelas="Budi",15,"9A"
print(nama,umur,kelas)
# Out:
# Budi 15 9A

# %%
berat_andi=berat_siti=berat_eko=45.5
print(berat_andi,berat_siti,berat_eko)
# Out:
# 45.5 45.5 45.5

# %% [markdown]
# #operasi di python

# %%
print(2+8)
# Out:
# 10

# %%
kelereng_dias=2
kelereng_azka=8
print(kelereng_dias+kelereng_azka)
# Out:
# 10

# %%
total_kelereng=8+2
print(total_kelereng)
# Out:
# 10

# %%
kelereng_azka:8
kelereng_dias:2
total_kelereng=kelereng_azka+kelereng_dias
print(total_kelereng)
# Out:
# 10

# %% [markdown]
# #latihan soal operasi python

# %%
1.
print(24*3)
# Out:
# 72

# %%
2.
total_jumlah_botol=24*3
print(total_jumlah_botol)
# Out:
# 72

# %%
3.
banyak_botol_per_kardus:24
jumlah_kardus:3
print(24*3)
# Out:
# 72

# %%
4.
banyak_botol_per_kardus:24
jumlah_kardus:3
total_jumlah_botol:72
print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #jenis tipe variabel

# %%
a = "handayani"
print(a)
type(a)
# Out:
# handayani
# str

# %%
b = -0.001
print(b)
type(b)
# Out:
# -0.001
# float

# %%
c = -50
print(c)
type(c)
# Out:
# -50
# int

# %%
d = True
print(d)
type(d)
# Out:
# True
# bool

# %%
d = true
print(d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3721722550.py in <cell line: 0>()
# ----> 1 d = true
#       2 print(d)
#       3 type(d)
#
# NameError: name 'true' is not defined

# %%
e = 1,89
print(e)
type(e)
# Out:
# (1, 89)
# tuple

# %%
x = "False"
print(x)
type(x)
# Out:
# False
# str

# %%
type(-500)
# Out:
# int

# %%
k = float(88)
print(k)
type(k)
# Out:
# 88.0
# float

# %%
z = float(-100)
print(z)
type(z)
# Out:
# -100.0
# float

# %% [markdown]
# #perubahan tipe variabel

# %%
f = 8.9
print(f)
type(f)
# Out:
# 8.9
# float

# %%
f = int(f)
print(f)
type(f)
# Out:
# 8
# int

# %%
g = -2.05
print(g)
type(g)
# Out:
# -2.05
# float

# %%
g = int(g)
print(g)
type(g)
# Out:
# -2
# int

# %%
g = bool(g)
print(g)
type(g)
# Out:
# True
# bool

# %%
h = True
print(h)
type(h)
# Out:
# True
# bool

# %%
h = int(h)
print(h)
type(h)
# Out:
# 1
# int

# %% [markdown]
# #operator perbandingan

# %%
print(6 >= 6)
# Out:
# True

# %%
print(8 == 9)
# Out:
# False

# %%
print(8 != 9)
# Out:
# True

# %%
print(8 < 10)
# Out:
# True

# %%
print(8 > 10)
# Out:
# False

# %% [markdown]
# #operator logika

# %%
print(not(5 <= 5))
# Out:
# False

# %%
print(8 > 7 and 6 < 5)
# Out:
# False

# %%
print(7 <= 1 or 2 != 2)
# Out:
# False

# %%
print(not(0 == 1 and 1 != 1))
# Out:
# True

# %%
print(not(5 < 10 or 5 <= 10))
# Out:
# False

# %% [markdown]
# tugas

# %%
tinggi_nino = 170
berat_nino = 55
umur_nino = 23

tinggi_minimal = 165
berat_minimal = 50
umur_maksimal = 25

print((tinggi_nino >= tinggi_minimal) and (berat_nino >= berat_minimal) and (umur_nino <= umur_maksimal))
# Out:
# True
